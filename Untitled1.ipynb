# %%
nums = [i for i in range(1,1001)]
string = "Practice Problems to Drill List Comprehension in Your Head."

# %%
[i for i in nums if (i % 8 ==0)]
# Out:
# [8,
#  16,
#  24,
#  32,
#  40,
#  48,
#  56,
#  64,
#  72,
#  80,
#  88,
#  96,
#  104,
#  112,
#  120,
#  128,
#  136,
#  144,
#  152,
#  160,
#  168,
#  176,
#  184,
#  192,
#  200,
#  208,
#  216,
#  224,
#  232,
#  240,
#  248,
#  256,
#  264,
#  272,
#  280,
#  288,
#  296,
#  304,
#  312,
#  320,
#  328,
#  336,
#  344,
#  352,
#  360,
#  368,
#  376,
#  384,
#  392,
#  400,
#  408,
#  416,
#  424,
#  432,
#  440,
#  448,
#  456,
#  464,
#  472,
#  480,
#  488,
#  496,
#  504,
#  512,
#  520,
#  528,
#  536,
#  544,
#  552,
#  560,
#  568,
#  576,
#  584,
#  592,
#  600,
#  608,
#  616,
#  624,
#  632,
#  640,
#  648,
#  656,
#  664,
#  672,
#  680,
#  688,
#  696,
#  704,
#  712,
#  720,
#  728,
#  736,
#  744,
#  752,
#  760,
#  768,
#  776,
#  784,
#  792,
#  800,
#  808,
#  816,
#  824,
#  832,
#  840,
#  848,
#  856,
#  864,
#  872,
#  880,
#  888,
#  896,
#  904,
#  912,
#  920,
#  928,
#  936,
#  944,
#  952,
#  960,
#  968,
#  976,
#  984,
#  992,
#  1000]

# %%
[i for i in nums if "6" in str(i)]
# Out:
# [6,
#  16,
#  26,
#  36,
#  46,
#  56,
#  60,
#  61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  69,
#  76,
#  86,
#  96,
#  106,
#  116,
#  126,
#  136,
#  146,
#  156,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  176,
#  186,
#  196,
#  206,
#  216,
#  226,
#  236,
#  246,
#  256,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  268,
#  269,
#  276,
#  286,
#  296,
#  306,
#  316,
#  326,
#  336,
#  346,
#  356,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  376,
#  386,
#  396,
#  406,
#  416,
#  426,
#  436,
#  446,
#  456,
#  460,
#  461,
#  462,
#  463,
#  464,
#  465,
#  466,
#  467,
#  468,
#  469,
#  476,
#  486,
#  496,
#  506,
#  516,
#  526,
#  536,
#  546,
#  556,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  567,
#  568,
#  569,
#  576,
#  586,
#  596,
#  600,
#  601,
#  602,
#  603,
#  604,
#  605,
#  606,
#  607,
#  608,
#  609,
#  610,
#  611,
#  612,
# ...

# %%
q3=len([char for char in string if char ==' '])
q3
# Out:
# 8

# %%
q4=''.join([char for char in string if char not in ['a','e','i','o','u','A','E','I','O','U']])
q4
# Out:
# 'Prctc Prblms t Drll Lst Cmprhnsn n Yr Hd.'

# %%
words=string.split(' ')
q5=[word for word in words if len(word)<5]
q5
# Out:
# ['to', 'List', 'in', 'Your']

# %%
q6={word:len(word) for word in words}
q6
# Out:
# {'Practice': 8,
#  'Problems': 8,
#  'to': 2,
#  'Drill': 5,
#  'List': 4,
#  'Comprehension': 13,
#  'in': 2,
#  'Your': 4,
#  'Head.': 5}

# %%
divisors=[i for i in range(2,10)]
#q7=[num for num in nums if num % [i for i in divisors]==0]
#divisors
nums[900]%divisors[3]
# Out:
# 1
